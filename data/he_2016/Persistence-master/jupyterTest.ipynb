# %%
from bgc_md.autoGeneratedMD_holger import generate_website, read_models_from_directory

# %%
generate_website
# Out:
# <function bgc_md.autoGeneratedMD_holger.generate_website>

# %%
models=read_models_from_directory("/home/cs/SoilR/Code/packageTests/bgc_md/bgc_md/SoilModels")
# Out:
# {J_1, Ls, Tx, f_T, J_2, f_W, A_l, LN}
# -------------
# Warning at initializing model S0004
# /home/cs/SoilR/Code/packageTests/bgc_md/bgc_md/SoilModels/Parton1987SoilSciSocAmJ.yaml
# Model run combination  '['Set 1', 'IV 1']' is invalid
# Parameter set 'Set 1' is incomplete
# Initial values 'IV 1' are incomplete
# -------------

# %%
mod1=models[0]

# %%
rm1=mod1.reservoir_model

# %%
rm1.__dict__
# Out:
# {'content_unit': 'kgCm^{-2}',
#  'input_fluxes': {0: i},
#  'internal_fluxes': {(0, 1): Y*h*k_1*r},
#  'output_fluxes': {0: Y*k_1*r*(-h + 1), 1: O*k_2*r},
#  'state_variables': ['Y', 'O'],
#  'state_vector': Matrix([
#  [Y],
#  [O]]),
#  'time_symbol': t,
#  'time_unit': 'yr'}

# %%
rm1.
# Out:
# Matrix([
# [Y],
# [O]])
